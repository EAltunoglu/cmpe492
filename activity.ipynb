# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
activities = pd.read_csv('original_data/activity.csv')

# %%
sns.boxplot(x=activities['steps'])
# Out:
# <AxesSubplot:xlabel='steps'>

# %%
sns.boxplot(x=activities['sedentaryminutes'])
# Out:
# <AxesSubplot:xlabel='sedentaryminutes'>

# %%
sns.boxplot(x=activities['lightlyactiveminutes'])
# Out:
# <AxesSubplot:xlabel='lightlyactiveminutes'>

# %%
sns.boxplot(x=activities['fairlyactiveminutes'])
# Out:
# <AxesSubplot:xlabel='fairlyactiveminutes'>

# %%
sns.boxplot(x=activities['veryactiveminutes'])
# Out:
# <AxesSubplot:xlabel='veryactiveminutes'>

# %%
x = activities.steps
y = activities.fatburnmins

plt.scatter(x, y)

# %%
x = activities.steps
y = activities.cardiomins

plt.scatter(x, y)

# %%
x = activities.meanrate
y = activities.sdrate

plt.scatter(x, y)

# %%
x = activities.steps
y = activities.floors

plt.scatter(x, y)

# %%
x = activities.meanrate
y = activities.sedentaryminutes

plt.scatter(x, y)

# %%
x = activities.meanrate
y = activities.lightlyactiveminutes

plt.scatter(x, y)

# %%
x = activities.meanrate
y = activities.fairlyactiveminutes

plt.scatter(x, y)

# %%
x = activities.meanrate
y = activities.veryactiveminutes

plt.scatter(x, y)

# %%
sns.displot(activities, x="sedentaryminutes")

# %%
sns.displot(activities, x="sedentaryminutes", y="complypercent")

# %%
sns.displot(activities, x="lightlyactiveminutes")

# %%
sns.displot(activities, x="lightlyactiveminutes", y="complypercent")

# %%
sns.displot(activities, x="fairlyactiveminutes")

# %%
sns.displot(activities, x="fairlyactiveminutes", y="complypercent")

# %%
sns.displot(activities, x="veryactiveminutes")

# %%
sns.displot(activities, x="veryactiveminutes", y="complypercent")

# %%
activities_light = activities.drop(['egoid', 'datadate', 'lowrangecal', 'fatburncal', 'cardiocal', 'peakcal'], axis=1)
sns.pairplot(activities_light)
