# %%
import pandas as pd
import seaborn as sns
import pandasql as psql
import numpy as np
import matplotlib.pyplot as plt
# from copy import deepcopy
# from scipy import stats
# from scipy.stats import chisquare

# %%
activities = pd.read_csv('original_data/activity.csv')

# %%
sns.boxplot(x=activities['steps'])
# Out:
# <AxesSubplot:xlabel='steps'>

# %%
sns.boxplot(x=activities['sedentaryminutes'])
# Out:
# <AxesSubplot:xlabel='sedentaryminutes'>

# %%
sns.boxplot(x=activities['lightlyactiveminutes'])
# Out:
# <AxesSubplot:xlabel='lightlyactiveminutes'>

# %%
sns.boxplot(x=activities['fairlyactiveminutes'])
# Out:
# <AxesSubplot:xlabel='fairlyactiveminutes'>

# %%
sns.boxplot(x=activities['veryactiveminutes'])
# Out:
# <AxesSubplot:xlabel='veryactiveminutes'>

# %%
activities_light = activities.drop(['egoid', 'datadate', 'lowrangecal', 'fatburncal', 'cardiocal', 'peakcal'], axis=1)
sns.pairplot(activities_light)
