# %%
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
import pandas as pd
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Eren\Desktop\proje\DataVisualisations-NetHealth.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Eren/Desktop/proje/DataVisualisations-NetHealth.ipynb#ch0000000?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/c%3A/Users/Eren/Desktop/proje/DataVisualisations-NetHealth.ipynb#ch0000000?line=1'>2</a> import matplotlib
#       <a href='vscode-notebook-cell:/c%3A/Users/Eren/Desktop/proje/DataVisualisations-NetHealth.ipynb#ch0000000?line=2'>3</a> import numpy as np
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# reading two csv files
activity = pd.read_csv('./activity.csv')
sleep = pd.read_csv('./sleep.csv')
grade = pd.read_csv('./grades.csv')
activity.head()
sleep.head()
grade.head()
# Out:
#    egoid  AcademicPeriod  CourseReferenceNumber FinalGrade
# 0  92552          201520                  26443         A-
# 1  92552          201520                  30358          A
# 2  92552          201610                  20712          B
# 3  92552          201710                  21026          A
# 4  92552          201510                  11726          B

# %%
data = pd.read_csv('./file_out3.csv')
data.head()
#print(len(data))
# Out:
#    egoid    dataDate  complypercent  meanrate     sdrate   steps  floors  \
# 0  92552  2015-07-28             59  56.03392  11.122536  1645.0     6.0
# 1  92552  2015-07-28             59  56.03392  11.122536  1645.0     6.0
# 2  92552  2015-07-28             59  56.03392  11.122536  1645.0     6.0
# 3  92552  2015-07-28             59  56.03392  11.122536  1645.0     6.0
# 4  92552  2015-07-28             59  56.03392  11.122536  1645.0     6.0
#
#    sedentaryminutes  lightlyactiveminutes  fairlyactiveminutes  ...  \
# 0             935.0                  80.0                  0.0  ...
# 1             935.0                  80.0                  0.0  ...
# 2             935.0                  80.0                  0.0  ...
# 3             935.0                  80.0                  0.0  ...
# 4             935.0                  80.0                  0.0  ...
#
#    timeoutofbed  bedtimedur  minstofallasleep  minsafterwakeup  minsasleep  \
# ...

# %%
import pandas as pd
data3 = pd.read_csv('./file_out3.csv')
data3.head()
print(len(data3))
# Out:
# 9330783

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
grade.sample(frac=1).head(n=20)
# Out:
#       egoid  AcademicPeriod  CourseReferenceNumber FinalGrade
# 4816  38815          201610                  14407          S
# 8798  15181          201620                  21514          A
# 82    73158          201610                  12064          A
# 813   27306          201710                  14108          A
# 2428  14737          201520                  22158          B
# 8806  15181          201820                  30447          A
# 9520  85503          201710                  21021          A
# 9829  14279          201610                  12106          A
# 5079  71985          201720                  29811          A
# 2805  89652          201820                  30249          A
# 6089  59097          201720                  20257          A
# 9182  67709          201620                  29623         B-
# 6355  93856          201720                  23749          A
# 4854  38815          201510                  11535         A-
# ...

# %%
grade.FinalGrade.unique()
# Out:
# array(['A-', 'A', 'B', 'B+', 'P', 'B-', 'C', 'C-', 'C+', 'S', nan, 'D',
#        'F', 'U', 'V'], dtype=object)

# %%
grade.CourseReferenceNumber.unique()
# Out:
# array([26443, 30358, 20712, ..., 14502, 22284, 17047])

# %%
    grade.AcademicPeriod.unique()
# Out:
# array([201520, 201610, 201710, 201510, 201810, 201820, 201620, 201720,
#        201600, 201700, 201800, 201900, 201400, 201910, 201750, 201300,
#        201500])

# %%
grade.describe(percentiles=[.01, .25, .5, .75, .99]).apply( 
	lambda s: s.apply('{0:.2f}'.format))
# Out:
#           egoid AcademicPeriod CourseReferenceNumber
# count  11070.00       11070.00              11070.00
# mean   54204.85      201659.27              19501.17
# std    25953.81         112.08               6712.60
# min    10237.00      201300.00                101.00
# 1%     13486.00      201510.00               3217.00
# 25%    31294.00      201520.00              13784.50
# 50%    50766.00      201620.00              20405.50
# 75%    76485.00      201720.00              23937.00
# 99%    98700.00      201820.00              31285.24
# max    99978.00      201910.00              73214.00

# %%
ego_ids = pd.DataFrame(grade.egoid.value_counts()) 
ego_ids.reset_index(level=0, inplace=True) 
ego_ids = ego_ids.sort_values(by='egoid', ascending=False).head(20) 
ego_ids.columns = ('egoid', 'size')
ego_ids
# Out:
#     egoid  size
# 0   57325    98
# 1   94215    78
# 2   63347    77
# 3   36117    74
# 4   73918    70
# 5   26858    69
# 6   65656    69
# 7   17470    65
# 8   36038    64
# 9   67106    63
# 10  82986    63
# 11  22138    62
# 13  44927    61
# 12  98700    61
# 14  95543    60
# 15  92566    60
# 16  70962    60
# 17  63138    60
# 18  44310    59
# 19  57443    59

# %%
#fuel types per year
import seaborn as sns 
 
sns.countplot(x="AcademicPeriod", hue="FinalGrade", data=data_all) 
plt.show()

# %%
#checking for outliers
sns.boxplot(x=data_all['egoid'])
# Out:
# <AxesSubplot:xlabel='egoid'>

# %%
sns.boxplot(x=data_all['steps'])
# Out:
# <AxesSubplot:xlabel='steps'>

# %%
#sleep_outcome
sleep_eff = pd.DataFrame(data_all.Efficiency.value_counts()) 
sleep_eff.reset_index(level=0, inplace=True) 
sleep_eff = sleep_eff.sort_values(by='Efficiency', ascending=False)
sleep_eff.columns = ('efficiency', 'size')
sleep_eff
# Out:
#        efficiency    size
# 0        1.000000  192981
# 1        0.937500   17944
# 2        0.941176   17380
# 3        0.950000   16249
# 4        0.928571   16168
# ...           ...     ...
# 20862    0.861224      38
# 20861    0.907855      38
# 20860    0.875458      38
# 20859    0.947902      38
# 20927    0.960546      38
#
# [20928 rows x 2 columns]

# %%
sns.boxplot(x=data_all['Efficiency'])
# Out:
# <AxesSubplot:xlabel='Efficiency'>

# %%
#sedentaryminutes
sedentaryminutes = pd.DataFrame(data_all.sedentaryminutes.value_counts()) 
sedentaryminutes.reset_index(level=0, inplace=True) 
sedentaryminutes = sedentaryminutes.sort_values(by='sedentaryminutes', ascending=False).head(20) 
sedentaryminutes.columns = ('sedentaryminutes', 'size')
sedentaryminutes
# Out:
#     sedentaryminutes   size
# 0              714.0  33672
# 1              681.0  32451
# 2              716.0  32332
# 3              715.0  32240
# 4              686.0  31933
# 5              690.0  31878
# 6              700.0  31664
# 7              688.0  31543
# 8              699.0  31509
# 9              706.0  31475
# 10             718.0  31199
# 11             660.0  31141
# 12             702.0  31112
# 13             693.0  31032
# 14             711.0  30988
# 15             679.0  30894
# 16             695.0  30889
# 17             677.0  30868
# 18             734.0  30860
# 19             683.0  30855

# %%
sns.boxplot(x=data_all['sedentaryminutes'])
# Out:
# <AxesSubplot:xlabel='sedentaryminutes'>

# %%
sns.boxplot(x=data_all['lightlyactiveminutes'])
# Out:
# <AxesSubplot:xlabel='lightlyactiveminutes'>

# %%
sns.boxplot(x=data_all['fairlyactiveminutes'])
# Out:
# <AxesSubplot:xlabel='fairlyactiveminutes'>

# %%
sns.boxplot(x=data_all['veryactiveminutes'])
# Out:
# <AxesSubplot:xlabel='veryactiveminutes'>

# %%
sns.boxplot(x=data_all['bedtimedur'])
# Out:
# <AxesSubplot:xlabel='bedtimedur'>

# %%
sns.boxplot(x=data_all['minstofallasleep'])
# Out:
# <AxesSubplot:xlabel='minstofallasleep'>

# %%
sns.boxplot(x=data_all['minsafterwakeup'])
# Out:
# <AxesSubplot:xlabel='minsafterwakeup'>

# %%
sns.boxplot(x=data_all['minsasleep'])
# Out:
# <AxesSubplot:xlabel='minsasleep'>

# %%
sns.boxplot(x=data_all['minsawake'])
# Out:
# <AxesSubplot:xlabel='minsawake'>

# %%
sns.boxplot(x=data_all['floors'])
# Out:
# <AxesSubplot:xlabel='floors'>

# %%
grade.head()
# Out:
#    egoid  AcademicPeriod  CourseReferenceNumber FinalGrade
# 0  92552          201520                  26443         A-
# 1  92552          201520                  30358          A
# 2  92552          201610                  20712          B
# 3  92552          201710                  21026          A
# 4  92552          201510                  11726          B

# %%
print(grade.AcademicPeriod)
# Out:
# 0        201520
# 1        201520
# 2        201610
# 3        201710
# 4        201510
#           ...
# 11065    201520
# 11066    201820
# 11067    201710
# 11068    201610
# 11069    201810
# Name: AcademicPeriod, Length: 11070, dtype: int64

# %%
len(grade.CourseReferenceNumber.unique())
# Out:
# 4503

# %%
len(grade.FinalGrade.unique())
# Out:
# 15

# %%
len(grade.AcademicPeriod.unique())
# Out:
# 17

# %%
x= (grade.AcademicPeriod.astype(int)).tolist()
y = grade.FinalGrade.tolist()
z = (grade.CourseReferenceNumber.astype(int)).tolist()
print(type(x[0]))
print(type(y))


T = (np.array(y)).reshape(-1,1)
T
# Out:
# <class 'int'>
# <class 'list'>
# array([['A-'],
#        ['A'],
#        ['B'],
#        ...,
#        ['B-'],
#        ['A'],
#        ['A']], dtype='<U32')

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder

encoder = OrdinalEncoder()
encoder.fit(T)
T_encoded = encoder.transform(T)

# %%
T_encoded
# Out:
# array([[1.],
#        [0.],
#        [2.],
#        ...,
#        [4.],
#        [0.],
#        [0.]])

# %%
colors = ['red','green','blue','purple', 'pink', 'orange','grey', 'black', 'yellow', 'brown']

fig = plt.figure(figsize=(8,8))
plt.scatter(x, T_encoded, c=z, cmap=matplotlib.colors.ListedColormap(colors))

cb = plt.colorbar()
loc = np.arange(0,max(T_encoded),max(T_encoded)/float(len(colors)))
cb.set_ticks(loc)
cb.set_ticklabels(colors)

# %%
colors = ['red','green','blue','purple', 'pink']

fig = plt.figure(figsize=(8,8))
plt.scatter(x, z, c=T_encoded, cmap=matplotlib.colors.ListedColormap(colors))

cb = plt.colorbar()
loc = np.arange(0,max(z),max(z)/float(len(colors)))
cb.set_ticks(loc)
cb.set_ticklabels(colors)

# %%
#code from stackoverflow
#https://stackoverflow.com/questions/12487060/matplotlib-color-according-to-class-labels
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

x = [4,8,12,16,1,4,9,16]
y = [1,4,9,16,4,8,12,3]
label = [0,1,2,3,0,1,2,3]
colors = ['red','green','blue','purple']

fig = plt.figure(figsize=(8,8))
plt.scatter(x, y, c=label, cmap=matplotlib.colors.ListedColormap(colors))

cb = plt.colorbar()
loc = np.arange(0,max(label),max(label)/float(len(colors)))
cb.set_ticks(loc)
cb.set_ticklabels(colors)

# %%
import pandas as pd
data = pd.read_csv('./combined_preprocessed.csv')
data.head()
# Out:
#    Unnamed: 0  egoid  dataDate  complypercent  meanrate     sdrate   steps  \
# 0           0  92552       209             59  56.03392  11.122536  1645.0
# 1           1  92552       209             59  56.03392  11.122536  1645.0
# 2           2  92552       209             59  56.03392  11.122536  1645.0
# 3           3  92552       209             59  56.03392  11.122536  1645.0
# 4           4  92552       209             59  56.03392  11.122536  1645.0
#
#    floors  sedentaryminutes  lightlyactiveminutes  ...  timeoutofbed  \
# 0     6.0             935.0                  80.0  ...       30360.0
# 1     6.0             935.0                  80.0  ...       30360.0
# 2     6.0             935.0                  80.0  ...       30360.0
# 3     6.0             935.0                  80.0  ...       30360.0
# 4     6.0             935.0                  80.0  ...       30360.0
#
#    bedtimedur  minstofallasleep  minsafterwakeup  minsasleep  minsawake  \
# ...

# %%
print(list(data))
# Out:
# ['Unnamed: 0', 'egoid', 'dataDate', 'complypercent', 'meanrate', 'sdrate', 'steps', 'floors', 'sedentaryminutes', 'lightlyactiveminutes', 'fairlyactiveminutes', 'veryactiveminutes', 'lowrangemins', 'fatburnmins', 'cardiomins', 'peakmins', 'lowrangecal', 'fatburncal', 'cardiocal', 'peakcal', 'timetobed', 'timeoutofbed', 'bedtimedur', 'minstofallasleep', 'minsafterwakeup', 'minsasleep', 'minsawake', 'AcademicPeriod', 'CourseReferenceNumber', 'year', 'FinalGrade']

# %%
x = data.steps
y = data.FinalGrade

plt.scatter(x, y)

# %%
x = data.sedentaryminutes
y = data.FinalGrade

plt.scatter(x, y)

# %%
x = data.lightlyactiveminutes
y = data.FinalGrade

plt.scatter(x, y)

# %%
x = data.fairlyactiveminutes
y = data.FinalGrade

plt.scatter(x, y)

# %%
x = data.veryactiveminutes
y = data.FinalGrade

plt.scatter(x, y)

# %%
x = data.timetobed
y = data.FinalGrade

plt.scatter(x, y)

# %%
x = data.timeoutofbed
y = data.FinalGrade

plt.scatter(x, y)

# %%
x = data.bedtimedur
y = data.FinalGrade

plt.scatter(x, y)

# %%
x = data.minstofallasleep
y = data.FinalGrade

plt.scatter(x, y)

# %%
x = data.minsasleep
y = data.FinalGrade

plt.scatter(x, y)

# %%
x = data.minsawake
y = data.FinalGrade

plt.scatter(x, y)

# %%
x = data.AcademicPeriod
y = data.FinalGrade

plt.scatter(x, y)

# %%
x = data.CourseReferenceNumber
y = data.FinalGrade

plt.scatter(x, y)

# %%
x = data.year
y = data.FinalGrade

plt.scatter(x, y)

# %%
x = data.timetobed
y = data.FinalGrade

plt.scatter(x, y)

# %%
x = data.bedtimedur
y = data.FinalGrade

plt.scatter(x, y)

# %%
sleep = pd.read_csv('./sleep.csv')
x = sleep.timetobed
y = sleep.Efficiency

plt.scatter(x, y)

# %%
x = sleep.minstofallasleep
y = sleep.Efficiency

plt.scatter(x, y)

# %%
x = sleep.minsafterwakeup
y = sleep.Efficiency

plt.scatter(x, y)

# %%
x = sleep.minsawake
y = sleep.Efficiency

plt.scatter(x, y)

# %%
x = sleep.minsasleep
y = sleep.Efficiency

plt.scatter(x, y)

# %%
sleep.head()
# Out:
#    egoid    dataDate timetobed timeoutofbed  bedtimedur  minstofallasleep  \
# 0  44869  2015-07-28  06:25:00     10:27:00         243                 0
# 1  44869  2015-07-29  03:26:30     07:21:30         236                 1
# 2  44869  2015-07-29  12:03:30     16:44:30         282                 3
# 3  44869  2015-07-30  06:27:30     14:31:30         485                 4
# 4  44869  2015-07-31  04:40:30     06:27:30         108                 0
#
#    minsafterwakeup  minsasleep  minsawake  Efficiency
# 0                0         232         11    0.954733
# 1                4         216         15    0.935065
# 2                0         267         12    0.956989
# 3                0         451         30    0.937630
# 4                0         100          8    0.925926

# %%
grades = pd.read_csv('./grades.csv')
grades.head()
# Out:
#    egoid  AcademicPeriod  CourseReferenceNumber FinalGrade
# 0  92552          201520                  26443         A-
# 1  92552          201520                  30358          A
# 2  92552          201610                  20712          B
# 3  92552          201710                  21026          A
# 4  92552          201510                  11726          B

# %%
#print((data_all.sedentaryminutes).loc['NA'])

data_all.loc[data_all['sedentaryminutes']== 'inf']
# Out:
# Empty DataFrame
# Columns: [egoid, dataDate, complypercent, meanrate, sdrate, steps, floors, sedentaryminutes, lightlyactiveminutes, fairlyactiveminutes, veryactiveminutes, lowrangemins, fatburnmins, cardiomins, peakmins, lowrangecal, fatburncal, cardiocal, peakcal, timetobed, timeoutofbed, bedtimedur, minstofallasleep, minsafterwakeup, minsasleep, minsawake, Efficiency, AcademicPeriod, CourseReferenceNumber, FinalGrade]
# Index: []
#
# [0 rows x 30 columns]

# %%
data_all.head()
# Out:
#    egoid    dataDate  complypercent  meanrate     sdrate   steps  floors  \
# 0  92552  2015-07-28             59  56.03392  11.122536  1645.0     6.0
# 1  92552  2015-07-28             59  56.03392  11.122536  1645.0     6.0
# 2  92552  2015-07-28             59  56.03392  11.122536  1645.0     6.0
# 3  92552  2015-07-28             59  56.03392  11.122536  1645.0     6.0
# 4  92552  2015-07-28             59  56.03392  11.122536  1645.0     6.0
#
#    sedentaryminutes  lightlyactiveminutes  fairlyactiveminutes  ...  \
# 0             935.0                  80.0                  0.0  ...
# 1             935.0                  80.0                  0.0  ...
# 2             935.0                  80.0                  0.0  ...
# 3             935.0                  80.0                  0.0  ...
# 4             935.0                  80.0                  0.0  ...
#
#    timeoutofbed  bedtimedur  minstofallasleep  minsafterwakeup  minsasleep  \
# ...

# %%
#boxplot 
#activity
sedentary = data_all["sedentaryminutes"]
lightly = data_all["lightlyactiveminutes"]
fairly = data_all["fairlyactiveminutes"]
very = data_all["veryactiveminutes"]
grade = data_all["FinalGrade"]

# %%
Q = [sedentary, lightly,fairly,very ]
sns.boxplot(x=sedentary, y=grade)
plt.show()

# %%
sns.boxplot(x=lightly, y=grade)
plt.show()

# %%
sns.boxplot(x=fairly, y=grade)
plt.show()

# %%
sns.boxplot(x=very, y=grade)
plt.show()

# %%
#sleep
timetobed = data_all["timetobed"]
timeoutofbed = data_all["timeoutofbed"]
bedtimedur = data_all["bedtimedur"]
minstofallasleep = data_all["minstofallasleep"]
minsasleep = data_all["minsasleep"]
grade = data_all["FinalGrade"]

# %%
sns.boxplot(x=timeoutofbed, y=grade)
plt.show()

# %%
sns.boxplot(x=bedtimedur, y=grade)
plt.show()

# %%
sns.boxplot(x=minstofallasleep, y=grade)
plt.show()

# %%
sns.boxplot(x=minsasleep, y=grade)
plt.show()

# %%
df = pd.DataFrame(data=dataframe, columns=["FFMC", "DMC", "DC", "ISI"])
sns.boxplot(x="variable", y="value", data=pd.melt(df))
plt.show()

# %%
data_all.sample(frac=1).head(n=20)
# Out:
#          egoid    dataDate  complypercent    meanrate     sdrate    steps  \
# 5265359  25197  2019-02-15             97   64.376976  18.811682  12176.0
# 7701408  33740  2016-03-16             94   77.514053  14.900552  16234.0
# 1670434  13486  2016-04-27             95   67.343086  16.218946  12499.0
# 4505153  14847  2016-05-03             96   76.629333  13.390374   8993.0
# 7180669  65656  2016-02-06             96   81.019455  17.283932  17658.0
# 5031816  15134  2017-05-07             55   63.463383  14.660203  12286.0
# 2955981  62617  2018-10-10             98   67.862480  15.942650  10788.0
# 4920290  67993  2016-02-06             98   83.810966  12.518626   6354.0
# 1381671  57359  2018-02-11            100   76.891289  14.826496   9505.0
# 7247796  36117  2016-08-05             44  104.553430  14.993127   6462.0
# 3813739  19735  2016-06-17            100   64.610954  19.009567   8862.0
# 5392325  10237  2016-01-18            100   69.847931  18.230062  11425.0
# ...

# %%
data_all.Efficiency.unique()
# Out:
# array([0.97136039, 0.93681318, 0.76190478, ..., 0.815534  , 0.86509633,
#        0.89450866])

# %%
subset = grade.iloc[:,[0,1,2,3]]
subset.head()
# Out:
#    egoid  AcademicPeriod  CourseReferenceNumber FinalGrade
# 0  92552          201520                  26443         A-
# 1  92552          201520                  30358          A
# 2  92552          201610                  20712          B
# 3  92552          201710                  21026          A
# 4  92552          201510                  11726          B

# %%
sns.pairplot(subset, hue='FinalGrade')

# %%
sns.pairplot(data, hue='FinalGrade')

# %%
sns.pairplot(sleep, hue='Efficiency')

# %%
sleep.head()
# Out:
#    egoid    dataDate timetobed timeoutofbed  bedtimedur  minstofallasleep  \
# 0  44869  2015-07-28  06:25:00     10:27:00         243                 0
# 1  44869  2015-07-29  03:26:30     07:21:30         236                 1
# 2  44869  2015-07-29  12:03:30     16:44:30         282                 3
# 3  44869  2015-07-30  06:27:30     14:31:30         485                 4
# 4  44869  2015-07-31  04:40:30     06:27:30         108                 0
#
#    minsafterwakeup  minsasleep  minsawake  Efficiency
# 0                0         232         11    0.954733
# 1                4         216         15    0.935065
# 2                0         267         12    0.956989
# 3                0         451         30    0.937630
# 4                0         100          8    0.925926

# %%
activity = pd.read_csv('./activity.csv')
activity.head()
# Out:
#    egoid    dataDate  complypercent    meanrate     sdrate   steps  floors  \
# 0  44869  2015-07-28             91   86.669746  11.979352  4034.0     1.0
# 1  44869  2015-07-29             97   87.975342   8.990446  3702.0     0.0
# 2  44869  2015-07-30            100   83.281448  16.863153  3660.0     0.0
# 3  44869  2015-07-31             80   91.707787  12.464956  6016.0    13.0
# 4  44869  2015-08-01             78  101.268140  10.464320  9846.0     5.0
#
#    sedentaryminutes  lightlyactiveminutes  fairlyactiveminutes  \
# 0            1034.0                 149.0                  2.0
# 1             769.0                 153.0                  0.0
# 2             795.0                 139.0                  3.0
# 3             954.0                 259.0                  0.0
# 4            1078.0                 282.0                 24.0
#
#    veryactiveminutes  lowrangemins  fatburnmins  cardiomins  peakmins  \
# ...

# %%
data_all = pd.read_csv('./file_out3.csv')
data_all.head()
# Out:
#    egoid    dataDate  complypercent  meanrate     sdrate   steps  floors  \
# 0  92552  2015-07-28             59  56.03392  11.122536  1645.0     6.0
# 1  92552  2015-07-28             59  56.03392  11.122536  1645.0     6.0
# 2  92552  2015-07-28             59  56.03392  11.122536  1645.0     6.0
# 3  92552  2015-07-28             59  56.03392  11.122536  1645.0     6.0
# 4  92552  2015-07-28             59  56.03392  11.122536  1645.0     6.0
#
#    sedentaryminutes  lightlyactiveminutes  fairlyactiveminutes  ...  \
# 0             935.0                  80.0                  0.0  ...
# 1             935.0                  80.0                  0.0  ...
# 2             935.0                  80.0                  0.0  ...
# 3             935.0                  80.0                  0.0  ...
# 4             935.0                  80.0                  0.0  ...
#
#    timeoutofbed  bedtimedur  minstofallasleep  minsafterwakeup  minsasleep  \
# ...

# %%
data_all.groupby(['egoid']).mean()
# Out:
#        complypercent   meanrate     sdrate         steps     floors  \
# egoid
# 10237      91.466731  74.623626  18.331194  12472.414658  14.385811
# 11002      94.678271  78.530092  16.536628  13300.429772  18.403167
# 13486      94.897778  66.260220  15.192966  11575.324444  25.022222
# 14279      96.452830  77.338477  16.620923  10939.002264  16.699623
# 14301      88.408269  70.738548  15.436526   9235.974160  10.927649
# ...              ...        ...        ...           ...        ...
# 97990      83.202216  74.543571  13.298761   6690.066482   9.340720
# 98462      87.638718  73.100794  14.736837  11469.678175  20.659679
# 98700      94.612800  81.146815  18.862949  16187.810400  27.857600
# 99733      90.964381  79.801410  14.363327   9302.738859   8.024043
# 99978      95.575758  61.789675  14.005620  11160.800505  17.917929
#
#        sedentaryminutes  lightlyactiveminutes  fairlyactiveminutes  \
# egoid
# ...

# %%
(np.isnan(dfnew - dfnew)).sum()
# Out:
# egoid                        0
# complypercent                0
# meanrate                     0
# sdrate                       0
# steps                     1106
# floors                   19995
# sedentaryminutes         41619
# lightlyactiveminutes     41619
# fairlyactiveminutes         88
# veryactiveminutes        41619
# lowrangemins                 0
# fatburnmins                  0
# cardiomins                   0
# peakmins                     0
# lowrangecal                  0
# fatburncal                   0
# cardiocal                    0
# peakcal                      0
# bedtimedur                   0
# minstofallasleep             0
# minsafterwakeup              0
# minsasleep                   0
# minsawake                    0
# Efficiency                   0
# AcademicPeriod               0
# CourseReferenceNumber        0
# dtype: int64

# %%
np.isfinite(dfnew - dfnew)
# Out:
#          egoid  complypercent  meanrate  sdrate  steps  floors  \
# 0         True           True      True    True   True    True
# 1         True           True      True    True   True    True
# 2         True           True      True    True   True    True
# 3         True           True      True    True   True    True
# 4         True           True      True    True   True    True
# ...        ...            ...       ...     ...    ...     ...
# 9330778   True           True      True    True   True    True
# 9330779   True           True      True    True   True    True
# 9330780   True           True      True    True   True    True
# 9330781   True           True      True    True   True    True
# 9330782   True           True      True    True   True    True
#
#          sedentaryminutes  lightlyactiveminutes  fairlyactiveminutes  \
# 0                    True                  True                 True
# ...

# %%
(np.isfinite(dfnew - dfnew)).sum()
# Out:
# egoid                    9330783
# complypercent            9330783
# meanrate                 9330783
# sdrate                   9330783
# steps                    9330783
# floors                   9330783
# sedentaryminutes         9330783
# lightlyactiveminutes     9330783
# fairlyactiveminutes      9330783
# veryactiveminutes        9330783
# lowrangemins             9330783
# fatburnmins              9330783
# cardiomins               9330783
# peakmins                 9330783
# lowrangecal              9330783
# fatburncal               9330783
# cardiocal                9330783
# peakcal                  9330783
# bedtimedur               9330783
# minstofallasleep         9330783
# minsafterwakeup          9330783
# minsasleep               9330783
# minsawake                9330783
# Efficiency               9330783
# AcademicPeriod           9330783
# CourseReferenceNumber    9330783
# dtype: int64

# %%
 dfnew.isna().sum()
# Out:
# egoid                    0
# complypercent            0
# meanrate                 0
# sdrate                   0
# steps                    0
# floors                   0
# sedentaryminutes         0
# lightlyactiveminutes     0
# fairlyactiveminutes      0
# veryactiveminutes        0
# lowrangemins             0
# fatburnmins              0
# cardiomins               0
# peakmins                 0
# lowrangecal              0
# fatburncal               0
# cardiocal                0
# peakcal                  0
# bedtimedur               0
# minstofallasleep         0
# minsafterwakeup          0
# minsasleep               0
# minsawake                0
# Efficiency               0
# AcademicPeriod           0
# CourseReferenceNumber    0
# dtype: int64

# %%
dfnew = dfnew.fillna(0)

# %%
(np.isnan(dfnew - dfnew)).sum()
# Out:
# egoid                    0
# complypercent            0
# meanrate                 0
# sdrate                   0
# steps                    0
# floors                   0
# sedentaryminutes         0
# lightlyactiveminutes     0
# fairlyactiveminutes      0
# veryactiveminutes        0
# lowrangemins             0
# fatburnmins              0
# cardiomins               0
# peakmins                 0
# lowrangecal              0
# fatburncal               0
# cardiocal                0
# peakcal                  0
# bedtimedur               0
# minstofallasleep         0
# minsafterwakeup          0
# minsasleep               0
# minsawake                0
# Efficiency               0
# AcademicPeriod           0
# CourseReferenceNumber    0
# dtype: int64

# %%
dfnew.shape
dfnew.astype(int)
# Out:
#          egoid  complypercent  meanrate  sdrate  steps  floors  \
# 0        92552             59        56      11   1645       6
# 1        92552             59        56      11   1645       6
# 2        92552             59        56      11   1645       6
# 3        92552             59        56      11   1645       6
# 4        92552             59        56      11   1645       6
# ...        ...            ...       ...     ...    ...     ...
# 9330778  35824             50        68      15  29474      83
# 9330779  35824             50        68      15  29474      83
# 9330780  35824             50        68      15  29474      83
# 9330781  35824             50        68      15  29474      83
# 9330782  35824             50        68      15  29474      83
#
#          sedentaryminutes  lightlyactiveminutes  fairlyactiveminutes  \
# 0                     935                    80                    0
# ...
